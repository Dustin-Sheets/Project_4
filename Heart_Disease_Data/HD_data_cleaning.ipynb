# %%
import pandas as pd

# %%
aust_hd_rates= pd.read_csv("Strategic_Measure_Percentage_of_residents_with_cardiovascular_disease.csv")

# %%
aust_hd_rates
# Out:
#    Date_Time  Year  Percent
# 0       2020  2020    0.071
# 1       2014  2014    0.044
# 2       2015  2015    0.049
# 3       2016  2016    0.062
# 4       2017  2017    0.062
# 5       2018  2018    0.070
# 6       2019  2019    0.047
# 7       2021  2021    0.051

# %%
clean_df = aust_hd_rates.drop(['Date_Time'], axis=1)

# %%
clean_df.to_csv('Austin_Cardivascular_Disease_Rates.csv')

# %%
hd_mortality= pd.read_csv("Heart_Disease_Mortality_Data_Among_US_Adults__35___by_State_Territory_and_County___2018-2020.csv")

# %%
hd_mortality
# Out:
#        Year LocationAbbr    LocationDesc GeographicLevel DataSource  \
# 0      2019           AK  Aleutians East          County       NVSS
# 1      2019           AK  Aleutians West          County       NVSS
# 2      2019           AK       Anchorage          County       NVSS
# 3      2019           AK          Bethel          County       NVSS
# 4      2019           AK     Bristol Bay          County       NVSS
# ...     ...          ...             ...             ...        ...
# 59089  2019           WY         Wyoming           State       NVSS
# 59090  2019           WY         Wyoming           State       NVSS
# 59091  2019           WY         Wyoming           State       NVSS
# 59092  2019           WY         Wyoming           State       NVSS
# 59093  2019           WY         Wyoming           State       NVSS
#
#                          Class                    Topic  Data_Value  \
# 0      Cardiovascular Diseases  Heart Disease Mortality       182.4
# ...

# %%
filtered_by_state=hd_mortality[hd_mortality['GeographicLevel']=='State']

# %%
filtered_by_state
# Out:
#        Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 522    2019           AK       Alaska           State       NVSS
# 523    2019           AK       Alaska           State       NVSS
# 524    2019           AK       Alaska           State       NVSS
# 525    2019           AK       Alaska           State       NVSS
# 526    2019           AK       Alaska           State       NVSS
# ...     ...          ...          ...             ...        ...
# 59089  2019           WY      Wyoming           State       NVSS
# 59090  2019           WY      Wyoming           State       NVSS
# 59091  2019           WY      Wyoming           State       NVSS
# 59092  2019           WY      Wyoming           State       NVSS
# 59093  2019           WY      Wyoming           State       NVSS
#
#                          Class                    Topic  Data_Value  \
# 522    Cardiovascular Diseases  Heart Disease Mortality       257.7
# ...

# %%
filtered2 = filtered_by_state[filtered_by_state['Stratification1']=='Overall']

# %%
filtered2
# Out:
#        Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 522    2019           AK       Alaska           State       NVSS
# 525    2019           AK       Alaska           State       NVSS
# 528    2019           AK       Alaska           State       NVSS
# 531    2019           AK       Alaska           State       NVSS
# 534    2019           AK       Alaska           State       NVSS
# ...     ...          ...          ...             ...        ...
# 59079  2019           WY      Wyoming           State       NVSS
# 59082  2019           WY      Wyoming           State       NVSS
# 59085  2019           WY      Wyoming           State       NVSS
# 59088  2019           WY      Wyoming           State       NVSS
# 59091  2019           WY      Wyoming           State       NVSS
#
#                          Class                    Topic  Data_Value  \
# 522    Cardiovascular Diseases  Heart Disease Mortality       257.7
# ...

# %%
columns_to_drop = ['GeographicLevel','LocationAbbr', 'DataSource', 'Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategory1','StratificationCategory2','TopicID','LocationID','Data_Value_Type','Data_Value_Unit','Class','Topic']

# %%
clean_df=filtered2.drop(columns=columns_to_drop)

# %%
clean_df
# Out:
#        Year LocationDesc  Data_Value Stratification1  \
# 522    2019       Alaska       257.7         Overall
# 525    2019       Alaska       239.3         Overall
# 528    2019       Alaska       300.2         Overall
# 531    2019       Alaska       161.9         Overall
# 534    2019       Alaska       173.0         Overall
# ...     ...          ...         ...             ...
# 59079  2019      Wyoming       306.9         Overall
# 59082  2019      Wyoming       281.0         Overall
# 59085  2019      Wyoming       194.9         Overall
# 59088  2019      Wyoming         NaN         Overall
# 59091  2019      Wyoming       338.4         Overall
#
#                           Stratification2    Y_lat    X_lon
# 522                               Overall  64.3173 -152.571
# 525                                 White  64.3173 -152.571
# 528                                 Black  64.3173 -152.571
# 531                              Hispanic  64.3173 -152.571
# ...

# %%
rename_columns={'Stratification1': 'Gender', 'Stratification2': 'Ethnicity','LocationDesc':'State','Data_Value':'Cases per 100,000'}

# %%
clean_df.rename(columns=rename_columns, inplace = True)

# %%
clean_df
#non gender specific
# Out:
#        Year    State  Cases per 100,000   Gender  \
# 522    2019   Alaska              257.7  Overall
# 525    2019   Alaska              239.3  Overall
# 528    2019   Alaska              300.2  Overall
# 531    2019   Alaska              161.9  Overall
# 534    2019   Alaska              173.0  Overall
# ...     ...      ...                ...      ...
# 59079  2019  Wyoming              306.9  Overall
# 59082  2019  Wyoming              281.0  Overall
# 59085  2019  Wyoming              194.9  Overall
# 59088  2019  Wyoming                NaN  Overall
# 59091  2019  Wyoming              338.4  Overall
#
#                                 Ethnicity    Y_lat    X_lon
# 522                               Overall  64.3173 -152.571
# 525                                 White  64.3173 -152.571
# 528                                 Black  64.3173 -152.571
# 531                              Hispanic  64.3173 -152.571
# 534            Asian and Pacific Islander  64.3173 -152.571
# ...

# %%
hd_mortality_white =clean_df[clean_df['Ethnicity']=='White']

# %%
hd_mortality_white.head()
#Heart Disease mortality amongst white population
# Out:
#       Year           State  Cases per 100,000   Gender Ethnicity    Y_lat  \
# 525   2019          Alaska              239.3  Overall     White  64.3173
# 1749  2019         Alabama              433.5  Overall     White  32.7949
# 3117  2019        Arkansas              435.2  Overall     White  34.8982
# 3153  2019  American Samoa                NaN  Overall     White -14.2766
# 3441  2019         Arizona              277.4  Overall     White  34.2921
#
#          X_lon
# 525  -152.5710
# 1749  -86.8267
# 3117  -92.4340
# 3153 -170.3670
# 3441 -111.6640

# %%
hd_mortality_white.to_csv('HD_mortality_White_Pop.csv')

# %%
hd_mortality_Black =clean_df[clean_df['Ethnicity']=='Black']

# %%
hd_mortality_Black.head()
#heart disease mortality amongst black population
# Out:
#       Year           State  Cases per 100,000   Gender Ethnicity    Y_lat  \
# 528   2019          Alaska              300.2  Overall     Black  64.3173
# 1752  2019         Alabama              490.0  Overall     Black  32.7949
# 3120  2019        Arkansas              472.4  Overall     Black  34.8982
# 3156  2019  American Samoa                NaN  Overall     Black -14.2766
# 3444  2019         Arizona              347.0  Overall     Black  34.2921
#
#          X_lon
# 528  -152.5710
# 1752  -86.8267
# 3120  -92.4340
# 3156 -170.3670
# 3444 -111.6640

# %%
hd_mortality_Black.to_csv('HD_mortality_Black_Pop.csv')

# %%
hd_mortality_Hispanic = clean_df[clean_df['Ethnicity']=='Hispanic']

# %%
hd_mortality_Hispanic.head()
# Out:
#       Year           State  Cases per 100,000   Gender Ethnicity    Y_lat  \
# 531   2019          Alaska              161.9  Overall  Hispanic  64.3173
# 1755  2019         Alabama              112.1  Overall  Hispanic  32.7949
# 3123  2019        Arkansas              162.2  Overall  Hispanic  34.8982
# 3159  2019  American Samoa                NaN  Overall  Hispanic -14.2766
# 3447  2019         Arizona              220.7  Overall  Hispanic  34.2921
#
#          X_lon
# 531  -152.5710
# 1755  -86.8267
# 3123  -92.4340
# 3159 -170.3670
# 3447 -111.6640

# %%
hd_mortality_Hispanic.to_csv('HD_mortality_Hispanic_Pop.csv')

# %%
hd_mortality_Asian =clean_df[clean_df['Ethnicity']=='Asian and Pacific Islander']

# %%
hd_mortality_Asian.head()
# Out:
#       Year           State  Cases per 100,000   Gender  \
# 534   2019          Alaska              173.0  Overall
# 1758  2019         Alabama              171.3  Overall
# 3126  2019        Arkansas              254.9  Overall
# 3162  2019  American Samoa                NaN  Overall
# 3450  2019         Arizona              155.3  Overall
#
#                        Ethnicity    Y_lat     X_lon
# 534   Asian and Pacific Islander  64.3173 -152.5710
# 1758  Asian and Pacific Islander  32.7949  -86.8267
# 3126  Asian and Pacific Islander  34.8982  -92.4340
# 3162  Asian and Pacific Islander -14.2766 -170.3670
# 3450  Asian and Pacific Islander  34.2921 -111.6640

# %%
hd_mortality_Asian.to_csv('HD_mortality_Asian_Pop.csv')

# %%
hd_mortality_Native =clean_df[clean_df['Ethnicity']=='American Indian and Alaskan Native']

# %%
hd_mortality_Native.head()
# Out:
#       Year           State  Cases per 100,000   Gender  \
# 537   2019          Alaska              423.5  Overall
# 1761  2019         Alabama              133.6  Overall
# 3129  2019        Arkansas              123.6  Overall
# 3165  2019  American Samoa                NaN  Overall
# 3453  2019         Arizona              268.1  Overall
#
#                                Ethnicity    Y_lat     X_lon
# 537   American Indian and Alaskan Native  64.3173 -152.5710
# 1761  American Indian and Alaskan Native  32.7949  -86.8267
# 3129  American Indian and Alaskan Native  34.8982  -92.4340
# 3165  American Indian and Alaskan Native -14.2766 -170.3670
# 3453  American Indian and Alaskan Native  34.2921 -111.6640

# %%
hd_mortality_Native.to_csv('HD_mortality_Native_Pop.csv')

# %%
Female= filtered_by_state[filtered_by_state['Stratification1']=='Female']

# %%
Female
# Out:
#        Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 524    2019           AK       Alaska           State       NVSS
# 527    2019           AK       Alaska           State       NVSS
# 530    2019           AK       Alaska           State       NVSS
# 533    2019           AK       Alaska           State       NVSS
# 536    2019           AK       Alaska           State       NVSS
# ...     ...          ...          ...             ...        ...
# 59081  2019           WY      Wyoming           State       NVSS
# 59084  2019           WY      Wyoming           State       NVSS
# 59087  2019           WY      Wyoming           State       NVSS
# 59090  2019           WY      Wyoming           State       NVSS
# 59093  2019           WY      Wyoming           State       NVSS
#
#                          Class                    Topic  Data_Value  \
# 524    Cardiovascular Diseases  Heart Disease Mortality       192.1
# ...

# %%
columns_to_drop2 = ['GeographicLevel','LocationAbbr', 'DataSource', 'Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategory1','StratificationCategory2','TopicID','LocationID','Data_Value_Type','Data_Value_Unit','Class','Topic','Y_lat','X_lon']

# %%
clean_df2=Female.drop(columns=columns_to_drop2)

# %%
clean_df2
# Out:
#        Year LocationDesc  Data_Value Stratification1  \
# 524    2019       Alaska       192.1          Female
# 527    2019       Alaska       177.0          Female
# 530    2019       Alaska       268.0          Female
# 533    2019       Alaska       133.5          Female
# 536    2019       Alaska       136.6          Female
# ...     ...          ...         ...             ...
# 59081  2019      Wyoming       231.5          Female
# 59084  2019      Wyoming         NaN          Female
# 59087  2019      Wyoming       121.0          Female
# 59090  2019      Wyoming         NaN          Female
# 59093  2019      Wyoming         NaN          Female
#
#                           Stratification2
# 524                               Overall
# 527                                 White
# 530                                 Black
# 533                              Hispanic
# 536            Asian and Pacific Islander
# ...                                   ...
# ...

# %%
clean_df3= clean_df2[clean_df2['Stratification2']=='Overall']
#filter data so that ethnicity is not a factor

# %%
clean_df3
# Out:
#        Year                LocationDesc  Data_Value Stratification1  \
# 524    2019                      Alaska       192.1          Female
# 1748   2019                     Alabama       345.9          Female
# 3116   2019                    Arkansas       338.1          Female
# 3152   2019              American Samoa         NaN          Female
# 3440   2019                     Arizona       208.2          Female
# 4502   2019                  California       207.7          Female
# 5672   2019                    Colorado       195.3          Female
# 5834   2019                 Connecticut       215.5          Female
# 5870   2019        District of Columbia       289.4          Female
# 5942   2019                    Delaware       238.5          Female
# 7166   2019                     Florida       210.2          Female
# 10046  2019                     Georgia       271.5          Female
# 10082  2019                        Guam       420.6          Female
# ...

# %%
df4=clean_df3.drop(['Stratification2'], axis = 1)

# %%
df4
# Out:
#        Year                       State  Cases per 100,000  Gender
# 524    2019                      Alaska              192.1  Female
# 1748   2019                     Alabama              345.9  Female
# 3116   2019                    Arkansas              338.1  Female
# 3152   2019              American Samoa                NaN  Female
# 3440   2019                     Arizona              208.2  Female
# 4502   2019                  California              207.7  Female
# 5672   2019                    Colorado              195.3  Female
# 5834   2019                 Connecticut              215.5  Female
# 5870   2019        District of Columbia              289.4  Female
# 5942   2019                    Delaware              238.5  Female
# 7166   2019                     Florida              210.2  Female
# 10046  2019                     Georgia              271.5  Female
# 10082  2019                        Guam              420.6  Female
# ...

# %%
rename_columns5={'Stratification1': 'Gender', 'LocationDesc':'State','Data_Value':'Cases per 100,000'}

# %%
df4.rename(columns=rename_columns5, inplace=True)

# %%
df4.head()
#heart disease mortality amongst Female Population
# Out:
#       Year           State  Cases per 100,000  Gender
# 524   2019          Alaska              192.1  Female
# 1748  2019         Alabama              345.9  Female
# 3116  2019        Arkansas              338.1  Female
# 3152  2019  American Samoa                NaN  Female
# 3440  2019         Arizona              208.2  Female

# %%
df4.to_csv('HD_mortality_Female_Pop.csv')

# %%
Male= filtered_by_state[filtered_by_state['Stratification1']=='Male']

# %%
Male
# Out:
#        Year LocationAbbr LocationDesc GeographicLevel DataSource  \
# 523    2019           AK       Alaska           State       NVSS
# 526    2019           AK       Alaska           State       NVSS
# 529    2019           AK       Alaska           State       NVSS
# 532    2019           AK       Alaska           State       NVSS
# 535    2019           AK       Alaska           State       NVSS
# ...     ...          ...          ...             ...        ...
# 59080  2019           WY      Wyoming           State       NVSS
# 59083  2019           WY      Wyoming           State       NVSS
# 59086  2019           WY      Wyoming           State       NVSS
# 59089  2019           WY      Wyoming           State       NVSS
# 59092  2019           WY      Wyoming           State       NVSS
#
#                          Class                    Topic  Data_Value  \
# 523    Cardiovascular Diseases  Heart Disease Mortality       327.1
# ...

# %%
columns_to_drop3 = ['GeographicLevel','LocationAbbr', 'DataSource', 'Data_Value_Footnote_Symbol','Data_Value_Footnote','StratificationCategory1','StratificationCategory2','TopicID','LocationID','Data_Value_Type','Data_Value_Unit','Class','Topic','Y_lat','X_lon']

# %%
clean_df4=Male.drop(columns=columns_to_drop3)

# %%
clean_df4
# Out:
#        Year LocationDesc  Data_Value Stratification1  \
# 523    2019       Alaska       327.1            Male
# 526    2019       Alaska       300.8            Male
# 529    2019       Alaska       309.9            Male
# 532    2019       Alaska       191.5            Male
# 535    2019       Alaska       219.6            Male
# ...     ...          ...         ...             ...
# 59080  2019      Wyoming       389.6            Male
# 59083  2019      Wyoming         NaN            Male
# 59086  2019      Wyoming       287.0            Male
# 59089  2019      Wyoming         NaN            Male
# 59092  2019      Wyoming       432.2            Male
#
#                           Stratification2
# 523                               Overall
# 526                                 White
# 529                                 Black
# 532                              Hispanic
# 535            Asian and Pacific Islander
# ...                                   ...
# ...

# %%
clean_df5= clean_df4[clean_df4['Stratification2']=='Overall']
#filter data so that ethnicity is not a factor

# %%
clean_df5
# Out:
#        Year                LocationDesc  Data_Value Stratification1  \
# 523    2019                      Alaska       327.1            Male
# 1747   2019                     Alabama       554.0            Male
# 3115   2019                    Arkansas       540.8            Male
# 3151   2019              American Samoa         NaN            Male
# 3439   2019                     Arizona       336.4            Male
# 4501   2019                  California       350.8            Male
# 5671   2019                    Colorado       305.3            Male
# 5833   2019                 Connecticut       348.0            Male
# 5869   2019        District of Columbia       433.9            Male
# 5941   2019                    Delaware       383.8            Male
# 7165   2019                     Florida       350.9            Male
# 10045  2019                     Georgia       437.9            Male
# 10081  2019                        Guam       719.6            Male
# ...

# %%
df6=clean_df5.drop(['Stratification2'], axis = 1)

# %%
df6.head()
# Out:
#       Year    LocationDesc  Data_Value Stratification1
# 523   2019          Alaska       327.1            Male
# 1747  2019         Alabama       554.0            Male
# 3115  2019        Arkansas       540.8            Male
# 3151  2019  American Samoa         NaN            Male
# 3439  2019         Arizona       336.4            Male

# %%
rename_columns6={'Stratification1': 'Gender','LocationDesc':'State','Data_Value':'Cases per 100,000'}

# %%
df6.rename(columns=rename_columns6, inplace=True)

# %%
df6.head()
# Out:
#       Year           State  Cases per 100,000 Gender
# 523   2019          Alaska              327.1   Male
# 1747  2019         Alabama              554.0   Male
# 3115  2019        Arkansas              540.8   Male
# 3151  2019  American Samoa                NaN   Male
# 3439  2019         Arizona              336.4   Male

# %%
df6.to_csv('HD_mortality_Male_Pop.csv')
